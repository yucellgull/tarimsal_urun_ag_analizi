# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('iller_veri.xlsx')
df2 = pd.read_excel('urunler.xlsx')

# %%
df
# Out:
#     plaka         il  rakim  ortalama_sicaklik  yagis_ortalama  nem_orani(%)
# 0       1      Adana     26               19.3           668.2            72
# 1       2   Adıyaman    679               17.4           715.1            68
# 2       3      Afyon   1025               11.7           451.4            64
# 3       4       Ağrı   1630                6.3           523.9            67
# 4      68    Aksaray    979               12.1           359.7            63
# ..    ...        ...    ...                ...             ...           ...
# 76     67       Uşak    911               12.6           557.6            66
# 77      5        Van   1727                9.5           393.2            70
# 78     76     Yalova      7               14.7           755.9            76
# 79     11     Yozgat   1313                9.2           571.4            65
# 80     72  Zonguldak      8               13.8          1228.1            79
#
# [81 rows x 6 columns]

# %%
df2
# Out:
#    Yıllık Ortalama Sıcaklık (°C) Nem (%) Yağış (mm)  Rakım (m)  \
# 0            2024-12-10 00:00:00   60-70    400-600      0-500
# 1            2024-12-10 00:00:00   50-60    300-500   500-1000
# 2                          12-14   60-70    500-700      0-500
# 3                          12-14   50-60    400-600   500-1000
# 4                          14-16   60-70    600-800      0-500
# 5                          14-16   50-60    500-700   500-1000
# 6                          12-14   50-60    300-500  1000-1500
# 7                          14-16   50-60    400-600  1000-1500
# 8                          16-18   50-60    500-700  1000-1500
# 9                          12-14   50-60    200-400  1500-2000
# 10                         14-16   50-60    300-500  1500-2000
# 11                         16-18   50-60    400-600  1500-2000
# 12                         18-20   60-70    600-800      0-500
# 13                         18-20   50-60    500-700   500-1000
# ...

# %%
df.hist(bins=10, figsize=(16,12)).hist(bins=10, figsize=(16,12))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.hist(bins=10, figsize=(16,12)).hist(bins=10, figsize=(16,12))
#       2 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'

# %% [markdown]
# jkkl
